# %% [markdown]
# # Visualization / Creating Flood Mask
# ### Author: Tadd Bindas
#
# This file reads the results of sfincs and writes the `hmax.tif` file, which describes flood extent

# %%
import os
from os.path import join
from os.path import abspath, basename, dirname, isabs, isfile
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import rioxarray as rxr
import xarray as xr

from hydromt_sfincs import SfincsModel, utils

# %%
sfincs_root = Path.cwd() / "../data/SFINCS/_ngwpc_data_test_maximum"
sf = SfincsModel(sfincs_root, mode="r")

# %%
sf.read_results()

# %%
ds = xr.open_dataset(sfincs_root / "sfincs_map.nc", engine="h5netcdf")

# %%
ds
# Out:
# <xarray.Dataset> Size: 188MB
# Dimensions:        (n: 469, m: 152, corner_n: 470, corner_m: 153, time: 313,
#                     timemax: 13, runtime: 1)
# Coordinates:
#     x              (n, m) float32 285kB ...
#     y              (n, m) float32 285kB ...
#   * time           (time) datetime64[ns] 3kB 2019-05-21 ... 2019-06-03
#   * timemax        (timemax) datetime64[ns] 104B 2019-05-22 ... 2019-06-03
# Dimensions without coordinates: n, m, corner_n, corner_m, runtime
# Data variables: (12/14)
#     inp            int32 4B ...
#     corner_x       (corner_n, corner_m) float32 288kB ...
#     corner_y       (corner_n, corner_m) float32 288kB ...
#     crs            int32 4B ...
#     sfincsgrid     int32 4B ...
#     msk            (n, m) float32 285kB ...
#     ...             ...
#     h              (time, n, m) float32 89MB ...
#     zsmax          (timemax, n, m) float32 4MB ...
#     hmax           (timemax, n, m) float32 4MB ...
#     total_runtime  (runtime) float32 4B ...
#     average_dt     (runtime) float32 4B ...
#     status         (runtime) float32 4B ...
# Attributes:
#     Conventions:                         Conventions = 'CF-1.6, SGRID-0.3
#     Build-Revision-Date-Netcdf-library:  4.8.1 of Sep 29 2021 09:36:14 $
#     Producer:                            SFINCS model: Super-Fast INundation ...
#     Build-Revision:                      $Rev: v2.1.2-Dollerup
#     Build-Date:                          $Date: 2024-12-20
#     title:                               SFINCS map netcdf output

# %%
sf.write_raster("results.hmax", compress="LZW")

# %% [markdown]
# Our flood extent file has been written. Now, it's time to compare the different methods to see how they did
